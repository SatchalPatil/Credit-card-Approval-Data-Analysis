# %%
import pandas as pd

# %%
data = pd.read_csv("Credit_card.csv")

# %%
data
# Out:
#        Ind_ID GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 0     5008827      M         Y             Y         0       180000.0
# 1     5009744      F         Y             N         0       315000.0
# 2     5009746      F         Y             N         0       315000.0
# 3     5009749      F         Y             N         0            NaN
# 4     5009752      F         Y             N         0       315000.0
# ...       ...    ...       ...           ...       ...            ...
# 1543  5028645      F         N             Y         0            NaN
# 1544  5023655      F         N             N         0       225000.0
# 1545  5115992      M         Y             Y         2       180000.0
# 1546  5118219      M         Y             N         0       270000.0
# 1547  5053790      F         Y             Y         0       225000.0
#
#                Type_Income                      EDUCATION  \
# 0                Pensioner               Higher education
# ...

# %%
label = pd.read_csv("Credit_card_label.csv")

# %%
label
# Out:
#        Ind_ID  label
# 0     5008827      1
# 1     5009744      1
# 2     5009746      1
# 3     5009749      1
# 4     5009752      1
# ...       ...    ...
# 1543  5028645      0
# 1544  5023655      0
# 1545  5115992      0
# 1546  5118219      0
# 1547  5053790      0
#
# [1548 rows x 2 columns]

# %%
data = data.merge(label , on="Ind_ID" , how = "left")

# %%
data #if label is 0 card aproved , if 1 then card denied
# Out:
#        Ind_ID GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 0     5008827      M         Y             Y         0       180000.0
# 1     5009744      F         Y             N         0       315000.0
# 2     5009746      F         Y             N         0       315000.0
# 3     5009749      F         Y             N         0            NaN
# 4     5009752      F         Y             N         0       315000.0
# ...       ...    ...       ...           ...       ...            ...
# 1543  5028645      F         N             Y         0            NaN
# 1544  5023655      F         N             N         0       225000.0
# 1545  5115992      M         Y             Y         2       180000.0
# 1546  5118219      M         Y             N         0       270000.0
# 1547  5053790      F         Y             Y         0       225000.0
#
#                Type_Income                      EDUCATION  \
# 0                Pensioner               Higher education
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data.head()
# Out:
#     Ind_ID GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 0  5008827      M         Y             Y         0       180000.0
# 1  5009744      F         Y             N         0       315000.0
# 4  5009752      F         Y             N         0       315000.0
# 6  5009754      F         Y             N         0       315000.0
# 7  5009894      F         N             N         0       180000.0
#
#             Type_Income                      EDUCATION Marital_status  \
# 0             Pensioner               Higher education        Married
# 1  Commercial associate               Higher education        Married
# 4  Commercial associate               Higher education        Married
# 6  Commercial associate               Higher education        Married
# 7             Pensioner  Secondary / secondary special        Married
#
#         Housing_type  Birthday_count  Employed_days  Mobile_phone  Work_Phone  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1496 entries, 0 to 1547
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Ind_ID          1496 non-null   int64
#  1   GENDER          1496 non-null   object
#  2   Car_Owner       1496 non-null   object
#  3   Propert_Owner   1496 non-null   object
#  4   CHILDREN        1496 non-null   int64
#  5   Annual_income   1496 non-null   float64
#  6   Type_Income     1496 non-null   object
#  7   EDUCATION       1496 non-null   object
#  8   Marital_status  1496 non-null   object
#  9   Housing_type    1496 non-null   object
#  10  Birthday_count  1496 non-null   float64
#  11  Employed_days   1496 non-null   int64
#  12  Mobile_phone    1496 non-null   int64
#  13  Work_Phone      1496 non-null   int64
#  14  Phone           1496 non-null   int64
#  15  EMAIL_ID        1496 non-null   int64
#  16  Family_Members  1496 non-null   int64
# ...

# %%
data.describe()
# Out:
#              Ind_ID     CHILDREN  Annual_income  Birthday_count  \
# count  1.496000e+03  1496.000000   1.496000e+03     1496.000000
# mean   5.079217e+06     0.415775   1.907750e+05   -16036.192513
# std    4.168109e+04     0.780784   1.131384e+05     4226.506557
# min    5.008827e+06     0.000000   3.375000e+04   -24946.000000
# 25%    5.045349e+06     0.000000   1.210500e+05   -19543.000000
# 50%    5.079010e+06     0.000000   1.660500e+05   -15686.000000
# 75%    5.115801e+06     1.000000   2.250000e+05   -12417.000000
# max    5.150412e+06    14.000000   1.575000e+06    -7705.000000
#
#        Employed_days  Mobile_phone   Work_Phone        Phone     EMAIL_ID  \
# count    1496.000000        1496.0  1496.000000  1496.000000  1496.000000
# mean    59290.681818           1.0     0.205882     0.304813     0.094251
# std    137766.774169           0.0     0.404480     0.460482     0.292276
# min    -14887.000000           1.0     0.000000     0.000000     0.000000
# ...

# %%
data.isna().sum()
# Out:
# Ind_ID            0
# GENDER            0
# Car_Owner         0
# Propert_Owner     0
# CHILDREN          0
# Annual_income     0
# Type_Income       0
# EDUCATION         0
# Marital_status    0
# Housing_type      0
# Birthday_count    0
# Employed_days     0
# Mobile_phone      0
# Work_Phone        0
# Phone             0
# EMAIL_ID          0
# Family_Members    0
# label_x           0
# label_y           0
# dtype: int64

# %%
data.isna().sum()
# Out:
# Ind_ID            0
# GENDER            0
# Car_Owner         0
# Propert_Owner     0
# CHILDREN          0
# Annual_income     0
# Type_Income       0
# EDUCATION         0
# Marital_status    0
# Housing_type      0
# Birthday_count    0
# Employed_days     0
# Mobile_phone      0
# Work_Phone        0
# Phone             0
# EMAIL_ID          0
# Family_Members    0
# label_x           0
# label_y           0
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.isna().sum()
# Out:
# Ind_ID            0
# GENDER            0
# Car_Owner         0
# Propert_Owner     0
# CHILDREN          0
# Annual_income     0
# Type_Income       0
# EDUCATION         0
# Marital_status    0
# Housing_type      0
# Birthday_count    0
# Employed_days     0
# Mobile_phone      0
# Work_Phone        0
# Phone             0
# EMAIL_ID          0
# Family_Members    0
# label_x           0
# label_y           0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
gender_income = data.groupby("GENDER")["Annual_income"].mean()

# %%
gender_income
# Out:
# GENDER
# F    172391.840021
# M    222485.245902
# Name: Annual_income, dtype: float64

# %%
gender_income.sort_values(ascending=False).head(2)
# Out:
# GENDER
# M    222485.245902
# F    172391.840021
# Name: Annual_income, dtype: float64

# %%
sns.barplot(x=gender_income.index , y = gender_income.values)
# Out:
# <Axes: xlabel='GENDER'>

# %%
sns.barplot(x=gender_income.index , y = gender_income.values)
plt.title("Avg Income by gender")
plt.show()

# %%
label_counts = data["label_x"].value_counts()
label_counts
# Out:
# label_x
# 0    1336
# 1     160
# Name: count, dtype: int64

# %%
plt.pie(label_counts, labels = ["Credit Approved", "Credit Denied"],autopct="%1.1f")
plt.title("Credits Approval Status")
plt.show()

# %%
data.groupby("Type_Income")["Annual_income"].mean()
# Out:
# Type_Income
# Commercial associate    233880.169972
# Pensioner               154964.866795
# State servant           210130.434783
# Working                 180154.579974
# Name: Annual_income, dtype: float64

# %%
data.groupby("Housing_type")["Family_Members"].sum()
# Out:
# Housing_type
# Co-op apartment           5
# House / apartment      2900
# Municipal apartment      92
# Office apartment         21
# Rented apartment         46
# With parents            175
# Name: Family_Members, dtype: int64

# %%
total_family = data.groupby("Housing_type")["Family_Members"].sum()
total_family
# Out:
# Housing_type
# Co-op apartment           5
# House / apartment      2900
# Municipal apartment      92
# Office apartment         21
# Rented apartment         46
# With parents            175
# Name: Family_Members, dtype: int64

# %%
plt.pie(total_family, labels = ["Co-op" , "House" , "Muncipal" ,"Office", "Rented", "w/parents"], autopct="%1.1f")
plt.title("Family Members acc. to Housing")
plt.show()

# %%
data.groupby("Propert_Owner")["Annual_income"].mean()
# Out:
# Propert_Owner
# N    183343.352601
# Y    194722.899181
# Name: Annual_income, dtype: float64

# %%
data.groupby("CHILDREN")["Annual_income"].sum()
# Out:
# CHILDREN
# 0     191703172.5
# 1      64218600.0
# 2      26226900.0
# 3       2845800.0
# 4        180000.0
# 14       225000.0
# Name: Annual_income, dtype: float64

# %%
sns.boxplot(x="Marital_status", y="Annual_income", data=data)
plt.title("Annual Income Variation by Marital Status")
plt.show()

# %%
marital_family = data.groupby("Marital_status")["Family_Members"].sum()

# %%
marital_family
# Out:
# Marital_status
# Civil marriage           243
# Married                 2521
# Separated                131
# Single / not married     263
# Widow                     81
# Name: Family_Members, dtype: int64

# %%
plt.pie(marital_family, labels= ["C","M","S","Si","W"], autopct="%1.1f")
plt.title("No. of family members variation wrt marital status")
plt.show()

# %%
data.boxplot(column="Annual_income", by = "EDUCATION")
plt.title("Annual Income var by Edu Level")
plt.show()

# %%
data
# Out:
#        Ind_ID GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 0     5008827      M         Y             Y         0       180000.0
# 1     5009744      F         Y             N         0       315000.0
# 4     5009752      F         Y             N         0       315000.0
# 6     5009754      F         Y             N         0       315000.0
# 7     5009894      F         N             N         0       180000.0
# ...       ...    ...       ...           ...       ...            ...
# 1542  5118268      M         Y             N         1       360000.0
# 1544  5023655      F         N             N         0       225000.0
# 1545  5115992      M         Y             Y         2       180000.0
# 1546  5118219      M         Y             N         0       270000.0
# 1547  5053790      F         Y             Y         0       225000.0
#
#                Type_Income                      EDUCATION  \
# 0                Pensioner               Higher education
# ...

# %%
data = data[["Car_Owner","Propert_Owner","Annual_income","EDUCATION","label_x"]]

# %%
data
# Out:
#      Car_Owner Propert_Owner  Annual_income                      EDUCATION  \
# 0            Y             Y       180000.0               Higher education
# 1            Y             N       315000.0               Higher education
# 4            Y             N       315000.0               Higher education
# 6            Y             N       315000.0               Higher education
# 7            N             N       180000.0  Secondary / secondary special
# ...        ...           ...            ...                            ...
# 1542         Y             N       360000.0  Secondary / secondary special
# 1544         N             N       225000.0              Incomplete higher
# 1545         Y             Y       180000.0               Higher education
# 1546         Y             N       270000.0  Secondary / secondary special
# 1547         Y             Y       225000.0               Higher education
#
#       label_x
# 0           1
# 1           1
# 4           1
# ...

# %%
from sklearn import preprocessing
labelencoder = preprocessing.LabelEncoder()

# %%
data["Car_Owner"] = labelencoder.fit_transform(data["Car_Owner"])
data["Propert_Owner"] = labelencoder.fit_transform(data["Propert_Owner"])
data["EDUCATION"] = labelencoder.fit_transform(data["EDUCATION"])
# Out:
# C:\Users\Satchal Patil\AppData\Local\Temp\ipykernel_30784\492187319.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Car_Owner"] = labelencoder.fit_transform(data["Car_Owner"])
# C:\Users\Satchal Patil\AppData\Local\Temp\ipykernel_30784\492187319.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Propert_Owner"] = labelencoder.fit_transform(data["Propert_Owner"])
# C:\Users\Satchal Patil\AppData\Local\Temp\ipykernel_30784\492187319.py:3: SettingWithCopyWarning:
# ...

# %%
data
# Out:
#       Car_Owner  Propert_Owner  Annual_income  EDUCATION  label_x
# 0             1              1       180000.0          1        1
# 1             1              0       315000.0          1        1
# 4             1              0       315000.0          1        1
# 6             1              0       315000.0          1        1
# 7             0              0       180000.0          4        1
# ...         ...            ...            ...        ...      ...
# 1542          1              0       360000.0          4        0
# 1544          0              0       225000.0          2        0
# 1545          1              1       180000.0          1        0
# 1546          1              0       270000.0          4        0
# 1547          1              1       225000.0          1        0
#
# [1496 rows x 5 columns]

# %%
X = data.iloc[: , : -1]
y = data.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , y_train , y_test = train_test_split(X,y , test_size = 0.2)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

scaled_X_train = scaler.fit_transform(X_train)
scaled_X_test = scaler.fit_transform(X_test)

# %%
from sklearn.metrics import accuracy_score
def modelperformance(predictions):
    print("Accuracy score on model is {}".format(accuracy_score(y_test,predictions)))

# %%
from sklearn.linear_model import LogisticRegression
log_model = LogisticRegression()
log_model.fit(scaled_X_train,y_train)
# Out:
# LogisticRegression()

# %%
log_predict = log_model.predict(scaled_X_test)
modelperformance(log_predict)
# Out:
# Accuracy score on model is 0.91

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
param_grid = {"n_neighbors": [3,5,7,9,11], 
              "weights" : ["uniform", "distance"],
              "algorithm": ["auto" , "kd_tree"]}
gridkn = GridSearchCV(KNeighborsClassifier(),param_grid,cv=2)
gridkn.fit(scaled_X_train,y_train)
# Out:
# GridSearchCV(cv=2, estimator=KNeighborsClassifier(),
#              param_grid={'algorithm': ['auto', 'kd_tree'],
#                          'n_neighbors': [3, 5, 7, 9, 11],
#                          'weights': ['uniform', 'distance']})

# %%
gridkn.best_params_
# Out:
# {'algorithm': 'auto', 'n_neighbors': 11, 'weights': 'uniform'}

# %%
knpreds = gridkn.predict(scaled_X_test)

# %%
modelperformance(knpreds)
# Out:
# Accuracy score on model is 0.8933333333333333

# %%
from sklearn.tree import DecisionTreeClassifier

param_grid = { "criterion":["gini","entropy"],
              "splitter":["best","random"],
              "max_depth":[None,10,20,30,40,50],
              "min_samples_split":[2,5,10],
              "min_samples_leaf":[1,2,4]
              }
grid_search_tree = GridSearchCV(estimator=DecisionTreeClassifier(),param_grid=param_grid)

# %%
grid_search_tree.fit(scaled_X_train,y_train)
# Out:
# GridSearchCV(estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 10, 20, 30, 40, 50],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'splitter': ['best', 'random']})

# %%
grid_search_tree.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': None,
#  'min_samples_leaf': 4,
#  'min_samples_split': 10,
#  'splitter': 'random'}

# %%
tree_preds = grid_search_tree.predict(scaled_X_test)

# %%
modelperformance(tree_preds)
# Out:
# Accuracy score on model is 0.8933333333333333

# %%
from sklearn.ensemble import RandomForestClassifier
rfc_model = RandomForestClassifier()

# %%
param_grid={
    "n_estimators" : [32,64,128,256],
    "max_features" : [2,3,4],
    "bootstrap" : [True , False],
    "oob_score" : [True , False]
}

# %%
grid_rfc = GridSearchCV(rfc_model , param_grid=param_grid)

# %%
grid_rfc.fit(scaled_X_train,y_train)
# Out:
# c:\Users\Satchal Patil\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 60 fits failed out of a total of 240.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 60 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Satchal Patil\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Satchal Patil\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1474, in wrapper
#     return fit_method(estimator, *args, **kwargs)
# ...

# %%
grid_rfc.best_params_
# Out:
# {'bootstrap': True, 'max_features': 3, 'n_estimators': 64, 'oob_score': False}

# %%
pred_rfc = grid_rfc.predict(scaled_X_test)

# %%
modelperformance(pred_rfc)
# Out:
# Accuracy score on model is 0.8866666666666667
